# %%
import cv2
from matplotlib import pyplot as plt
import glob
import os

# %%
dataroot="data/dataset"

# %%
list_images=glob.glob(os.path.join(dataroot,"*.jpg"))
list_anotations=[x[:-3]+"json" for x in list_images]
print("len images ",len(list_images))
print("len annotations ",len(list_anotations))
# Out:
# len images  2146
# len annotations  2146

# %%
print(list_images[0:10])
print(list_anotations[0:10])
# Out:
# ['data/dataset/1570.jpg', 'data/dataset/1101.jpg', 'data/dataset/1931.jpg', 'data/dataset/1466.jpg', 'data/dataset/322.jpg', 'data/dataset/2109.jpg', 'data/dataset/205.jpg', 'data/dataset/2080.jpg', 'data/dataset/440.jpg', 'data/dataset/143.jpg']
# ['data/dataset/1570.json', 'data/dataset/1101.json', 'data/dataset/1931.json', 'data/dataset/1466.json', 'data/dataset/322.json', 'data/dataset/2109.json', 'data/dataset/205.json', 'data/dataset/2080.json', 'data/dataset/440.json', 'data/dataset/143.json']

# %%
import random
id=random.randint(0,len(list_anotations))
image=cv2.imread(list_images[id])
plt.imshow(image)
plt.title('my picture')
plt.show()

# %%
path_annotation=list_anotations[id]
with open(path) as json_file:
    data = json.load(json_file)
    width=data['imageWidth']
    height=data['imageHeight']
    for shape in data['shapes']
        points=shape["points"]
        print(points)
